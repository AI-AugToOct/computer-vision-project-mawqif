# %%
# %pip install ultralytics opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio
# %pip install "ultralytics.nn.modules.conv"
# Out:
# ERROR: Could not find a version that satisfies the requirement ultralytics.nn.modules.conv (from versions: none)
# ERROR: No matching distribution found for ultralytics.nn.modules.conv
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torchvision==0.15.2
# Out:
# ...
#   Using cached torchvision-0.15.2-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1a0
#     Uninstalling torchvision-0.13.1a0:
#       Successfully uninstalled torchvision-0.13.1a0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Path to your dataset directory
dataset_path = "dataset8/data.yaml"

# Load the YOLOv8 model (pretrained version)
model = YOLO("yolov8s.pt")  # You can use yolov8s.pt, yolov8m.pt, or yolov8l.pt depending on your hardware and accuracy needs

# Train the model
model.train(data=dataset_path, epochs=20, imgsz=640)  # You can adjust epochs and image size
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.10 torch-2.0.1 CPU
# ...

# %%
from ultralytics import YOLO
dataset_path = "dataset11/data.yaml"

# Load the YOLOv11 model (replace with the correct path)
model = YOLO("yolo11s.pt")

# Train the model with your dataset
model.train(data=dataset_path, epochs=20, imgsz=640)
# Out:
# Ultralytics 8.3.202 🚀 Python-3.10.10 torch-2.0.1 CPU (Apple M1)
# ...

# %%
# Paths to the models best epoch. you can also put last.pt
yolo8_model_path = 'runs/detect/train2/weights/best.pt' 
yolo11_model_path = 'runs/detect/train10/weights/best.pt'  

# Load the models
model_yolo8 = YOLO(yolo8_model_path)
model_yolo11 = YOLO(yolo11_model_path)

test_image = 

# Run inference
results_yolo8 = model_yolo8(test_image)
results_yolo11 = model_yolo11(test_image)

# Function to visualize results using OpenCV
def show_results(results, title='Prediction'):
    for result in results:
        img = result.plot()  # returns a numpy image with bboxes drawn
        plt.figure(figsize=(12, 8))
        plt.title(title)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

# Show predictions
show_results(results_yolo8, 'YOLOv8 Prediction')
show_results(results_yolo11, 'YOLOv11 Prediction')
